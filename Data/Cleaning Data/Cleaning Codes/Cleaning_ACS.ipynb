# %%
# Import dependencies.
import pandas as pd
import numpy as np

# %%
# File to Load
acs_data = "../Raw Data/CY2015_2019_AmerCommunSurvey.csv"

# %%
# Read the school data file and store it in a Pandas DataFrame.
acs_df = pd.read_csv(acs_data)
acs_df
# Out:
#          ZIP         CITY STATE  2019_Total_Population  2019_Total_Households  \
# 0       1001       Agawam    MA                  17030                   7339
# 1       1002      Amherst    MA                  35292                   9795
# 2       1003      Amherst    MA                   5991                      3
# 3       1005        Barre    MA                   5285                   1969
# 4       1007  Belchertown    MA                  14977                   5555
# ...      ...          ...   ...                    ...                    ...
# 32104  99923        Hyder    AK                     14                     14
# 32105  99925      Klawock    AK                    807                    279
# 32106  99926   Metlakatla    AK                   1654                    487
# 32107  99929     Wrangell    AK                   2486                   1019
# 32108  99950    Ketchikan    AK                    909                    367
#
# ...

# %%
# Find unique values
acs_df.nunique(axis=0,dropna=True,)
# Out:
# ZIP                                                  32109
# CITY                                                 16944
# STATE                                                   51
# 2019_Total_Population                                15456
# 2019_Total_Households                                10625
#                                                      ...
# 2019_Renter_Households                                6291
# 2019_Median_Contract_Rent_(HHs_Paying_Cash_Rent)      2124
# 2019_Average_Contract_Rent_(HHs_Paying_Cash_Rent)     1579
# 2019_Median_Gross_Rent_(HHs_Paying_Cash_Rent)         2128
# 2019_Average_Gross_Rent_(HHs_Paying_Cash_Rent)        1586
# Length: 221, dtype: int64

# %%
# Drop 
acs_df = acs_df.drop('2019_Total_Households', axis=1)
acs_df = acs_df.drop('2019_Renter_Households', axis=1)
acs_df = acs_df.drop('2019_Median_Contract_Rent_(HHs_Paying_Cash_Rent)', axis=1)
acs_df = acs_df.drop('2019_Average_Contract_Rent_(HHs_Paying_Cash_Rent)', axis=1)
acs_df = acs_df.drop('2019_Median_Gross_Rent_(HHs_Paying_Cash_Rent)', axis=1)
acs_df = acs_df.drop('2019_Average_Gross_Rent_(HHs_Paying_Cash_Rent)', axis=1)
acs_df = acs_df.drop('2019_Total_Housing_Units', axis=1)
acs_df = acs_df.drop('2019_Owner_Households', axis=1)
acs_df = acs_df.drop('2019_Median_Home_Value', axis=1)
acs_df = acs_df.drop('2019_Average_Home_Value', axis=1)
acs_df = acs_df.drop('2019_Average_Value_of_Owner_Households_w/Mortgage', axis=1)
acs_df = acs_df.drop('2019_Average_Value_of_Owner_Households_w/No_Mortgage', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_Under_5_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_5_to_9_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_10_to_14_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_15_to_19_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_70_to_74_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_75_to_79_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_80_to_84_Years', axis=1)
acs_df = acs_df.drop('2019_Total_Population:_85_Years_and_Over', axis=1)
acs_df = acs_df.drop('2019_Male_Population', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_Under_5_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_5_to_9_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_10_to_14_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_15_to_19_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_20_to_24_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_25_to_29_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_30_to_34_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_35_to_39_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_45_to_49_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_40_to_44_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_50_to_54_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_55_to_59_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_60_to_64_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_65_to_69_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_70_to_74_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_75_to_79_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_80_to_84_Years', axis=1)
acs_df = acs_df.drop('2019_Male_Population:_85_Years_and_Over', axis=1)
acs_df = acs_df.drop('2019_Female_Population', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_Under_5_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_5_to_9_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_10_to_14_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_15_to_19_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_20_to_24_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_25_to_29_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_30_to_34_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_35_to_39_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_45_to_49_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_40_to_44_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_50_to_54_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_55_to_59_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_60_to_64_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_65_to_69_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_70_to_74_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_75_to_79_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_80_to_84_Years', axis=1)
acs_df = acs_df.drop('2019_Female_Population:_85_Years_and_Over', axis=1)
#acs_df = acs_df.drop('2019_Population_Age_25+_by_Educational_Attainment_Base', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_No_Schooling', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_9th-12th_(No_Diploma)', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_High_School_Diploma', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_GED/Alternative_Credential', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_Some_College/No_Degree', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_Associate_Degree', axis=1)
#acs_df = acs_df.drop('Field71', axis=1)
#acs_df = acs_df.drop('Field72', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_Professional_School_Degree', axis=1)
#acs_df = acs_df.drop('2019_Pop_Age_25+:_Doctorate_Degree', axis=1)
acs_df = acs_df.drop('2019_Population_Age_15+_by_Marital_Status_Base', axis=1)
acs_df = acs_df.drop('2019_Population_Age_15+:_Never_Married', axis=1)
acs_df = acs_df.drop('2019_Population_Age_15+:_Married', axis=1)
acs_df = acs_df.drop('2019_Population_Age_15+:_Widowed', axis=1)
acs_df = acs_df.drop('2019_Population_Age_15+:_Divorced', axis=1)
acs_df = acs_df.drop('2019_Population_Age_65+', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Households', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_Households', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_HHs:_Householder', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_HHs:_Spouse', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_HHs:_Parent', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_HHs:_Parent-in-law', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_HHs:_Other_Relative', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Family_HHs:_Nonrelative', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Nonfamily_Households', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Nonfamily_HHs:_Householder', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Nonfamily_HHs:_Nonrelative', axis=1)
acs_df = acs_df.drop('2019_Pop_65+_Living_in_Group_Quarters', axis=1)
acs_df = acs_df.drop('2019_Workers_Age_16+', axis=1)
acs_df = acs_df.drop('2019_Worked_in_State_and_County_of_Residence', axis=1)
acs_df = acs_df.drop('2019_Worked_in_State_but_Outside_County_of_Residence', axis=1)
acs_df = acs_df.drop('2019_Worked_Outside_State_of_Residence', axis=1)
acs_df = acs_df.drop('2019_Industry:_Agriculture/Fishing/Hunting', axis=1)
acs_df = acs_df.drop('2019_Industry:_Mining/Oil_&_Gas_Extraction', axis=1)
acs_df = acs_df.drop('2019_Industry:_Construction', axis=1)
acs_df = acs_df.drop('2019_Industry:_Manufacturing', axis=1)
acs_df = acs_df.drop('2019_Industry:_Wholesale_Trade', axis=1)
acs_df = acs_df.drop('2019_Industry:_Retail_Trade', axis=1)
acs_df = acs_df.drop('2019_Industry:_Transportation/Warehousing', axis=1)
acs_df = acs_df.drop('2019_Industry:_Utilities', axis=1)
acs_df = acs_df.drop('2019_Industry:_Information', axis=1)
acs_df = acs_df.drop('2019_Industry:_Finance/Insurance', axis=1)
acs_df = acs_df.drop('2019_Industry:_Real_Estate/Rental/Leasing', axis=1)
acs_df = acs_df.drop('2019_Industry:_Professional/Scientific/Technical_Services', axis=1)
acs_df = acs_df.drop('2019_Industry:_Management_of_Companies_and_Enterprises', axis=1)
acs_df = acs_df.drop('2019_Industry:_Administrative/Support/Waste_Management_Services', axis=1)
acs_df = acs_df.drop('2019_Industry:_Educational_Services', axis=1)
acs_df = acs_df.drop('2019_Industry:_Health_Care/Social_Assistance', axis=1)
acs_df = acs_df.drop('2019_Industry:_Arts/Entertainment/Recreation', axis=1)
acs_df = acs_df.drop('2019_Industry:_Accommodation/Food_Services', axis=1)
acs_df = acs_df.drop('2019_Industry:_Other_Services_(excluding_Public_Administration)', axis=1)
acs_df = acs_df.drop('2019_Industry:_Public_Administration', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Management', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Business/Financial', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Computer_and_Mathematical', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Architecture/Engineering', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Life/Physical/Social_Science', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Community/Social_Services', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Legal', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Education/Training/Library', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Arts/Entertainment/Sports/Media', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Healthcare_Practitioner/Technologists/Technicia', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Healthcare_Support', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Protective_Service', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Food_Preparation/Serving_Related', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Building/Grounds_Cleaning/Maintenance', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Personal_Care/Service', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Sales/Related', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Office/Administrative_Support', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Farming/Fishing/Forestry', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Construction/Extraction', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Installation/Maintenance/Repair', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Production', axis=1)
acs_df = acs_df.drop('2019_Occupation:_Transport/Material_Moving', axis=1)
acs_df = acs_df.drop('2019_Pop_19-34:_One_Type_of_Health_Insurance', axis=1)
acs_df = acs_df.drop('2019_Pop_19-34:_Employer-Based_Health_Ins_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_19-34:_Direct-Purchase_Health_Ins_Only', axis=1)
acs_df = acs_df.drop('2019_Population_19-34:_Medicare_Coverage_Only', axis=1)
acs_df = acs_df.drop('2019_Population_19-34:_TRICARE/Military_Health_Only', axis=1)
acs_df = acs_df.drop('2019_Population_19-34:_VA_Health_Care_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_19-34:_2+_Types_of_Health_Insurance', axis=1)
acs_df = acs_df.drop('2019_Population_19-34:_Medicaid_Coverage_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_19-34:_No_Health_Insurance_Coverage', axis=1)
acs_df = acs_df.drop('2019_Civilian_Noninstitutionalized_Pop_35-64', axis=1)
acs_df = acs_df.drop('2019_Pop_35-64:_One_Type_of_Health_Insurance', axis=1)
acs_df = acs_df.drop('2019_Pop_35-64:_Employer-Based_Health_Ins_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_35-64:_Direct-Purchase_Health_Ins_Only', axis=1)
acs_df = acs_df.drop('2019_Population_35-64:_Medicaid_Coverage_Only', axis=1)
acs_df = acs_df.drop('2019_Population_35-64:_Medicare_Coverage_Only', axis=1)
acs_df = acs_df.drop('2019_Population_35-64:_TRICARE/Military_Health_Only', axis=1)
acs_df = acs_df.drop('2019_Population_35-64:_VA_Health_Care_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_35-64:_2+_Types_of_Health_Insurance', axis=1)
acs_df = acs_df.drop('2019_Pop_35-64:_No_Health_Insurance_Coverage', axis=1)
acs_df = acs_df.drop('2019_Civilian_Noninstitutionalized_Pop_Age_65+', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_One_Type_of_Health_Insurance', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_Employer-Based_Health_Ins_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_Direct-Purchase_Health_Ins_Only', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_Medicare_Coverage_Only', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_TRICARE/Military_Health_Only', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_VA_Health_Care_Only', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_2+_Types_of_Health_Insurance', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_No_Health_Insurance_Coverage', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_Employer-Based_&_Direct-Purchase_Hlth', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_Employer-Based_Hlth_&_Medicare', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_Direct-Purchase_Hlth_&_Medicare', axis=1)
acs_df = acs_df.drop('2019_Population_65+:_Medicare_&_Medicaid_Coverage', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_Other_Private_Health_Ins_Combos', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_Other_Public_Health_Ins_Combos', axis=1)
acs_df = acs_df.drop('2019_Pop_65+:_Other_Health_Ins_Combinations', axis=1)
acs_df = acs_df.drop('2019_Population_in_Households', axis=1)
acs_df = acs_df.drop('2019_Population_18-64_in_Households', axis=1)
acs_df = acs_df.drop('2019_Family_Households', axis=1)
acs_df = acs_df.drop('2019_Nonfamily_Households', axis=1)
acs_df = acs_df.drop('2019_Households_with_Population_Age_<18', axis=1)
acs_df = acs_df.drop('2019_Households_w/Population_Age_65+', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_<_$10000', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$10000-$14999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$15000-$19999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$20000-$24999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$25000-$29999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$30000-$34999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$35000-$39999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$40000-$44999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$45000-$49999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$50000-$59999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$60000-$74999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$75000-$99999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$100000-$124999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$125000-$149999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$150000-$199999', axis=1)
acs_df = acs_df.drop('2019_Households_by_Income:_$200000+', axis=1)
acs_df = acs_df.drop('2019_HH_Income_&_HHr_Age_15-24_Base', axis=1)
#acs_df = acs_df.drop('2019_Median_HH_Income:_HHr_Age_15-24', axis=1)
acs_df = acs_df.drop('2019_Average_HH_Income:_Householder_15-24', axis=1)
acs_df = acs_df.drop('2019_HH_Income_&_HHr_Age_25-44_Base', axis=1)
#acs_df = acs_df.drop('2019_Median_HH_Income:_HHr_Age_25-44', axis=1)
acs_df = acs_df.drop('2019_Average_HH_Income:_Householder_25-44', axis=1)
acs_df = acs_df.drop('2019_HH_Income_&_HHr_Age_45-64_Base', axis=1)
#acs_df = acs_df.drop('2019_Median_HH_Income:_HHr_Age_45-64', axis=1)
acs_df = acs_df.drop('2019_Average_HH_Income:_Householder_45-64', axis=1)
acs_df = acs_df.drop('2019_HH_Income_&_HHr_Age_65+_Base', axis=1)
#acs_df = acs_df.drop('2019_Median_HH_Income:_HHr_Age_65+', axis=1)
acs_df = acs_df.drop('2019_Households_Below_the_Poverty_Level', axis=1)
acs_df = acs_df.drop('2019_Households_with_1+_Persons_with_a_Disability', axis=1)
acs_df = acs_df.drop('2019_HHs_with_No_Persons_with_a_Disability', axis=1)
acs_df = acs_df.drop('2019_Average_HH_Income:_Householder_65+', axis=1)
acs_df = acs_df.drop('2019_Median_Household_Income', axis=1)
acs_df = acs_df.drop('2019_Average_HH_Income', axis=1)
acs_df = acs_df.drop('2019_Total_Population', axis=1)
acs_df
# Out:
#          ZIP         CITY STATE  2019_Total_Population:_20_to_24_Years  \
# 0       1001       Agawam    MA                                    650
# 1       1002      Amherst    MA                                  11249
# 2       1003      Amherst    MA                                   2734
# 3       1005        Barre    MA                                    414
# 4       1007  Belchertown    MA                                   1252
# ...      ...          ...   ...                                    ...
# 32104  99923        Hyder    AK                                      0
# 32105  99925      Klawock    AK                                     41
# 32106  99926   Metlakatla    AK                                    107
# 32107  99929     Wrangell    AK                                     51
# 32108  99950    Ketchikan    AK                                     30
#
#        2019_Total_Population:_25_to_29_Years  \
# 0                                       1027
# ...

# %%
# Renaming '71' and '72' to correct names
acs_df.rename(columns={"Field71":"2019_Pop_Age_25+:_Bachelors_Degree"}, inplace=True)
acs_df.rename(columns={"Field72":"2019_Pop_Age_25+:_Graduate_Degree"}, inplace=True)

# %%
# Check for missing values in the data.
acs_df.isnull().sum()
# Out:
# ZIP                                                       0
# CITY                                                      0
# STATE                                                     0
# 2019_Total_Population:_20_to_24_Years                     0
# 2019_Total_Population:_25_to_29_Years                     0
# 2019_Total_Population:_30_to_34_Years                     0
# 2019_Total_Population:_35_to_39_Years                     0
# 2019_Total_Population:_40_to_44_Years                     0
# 2019_Total_Population:_45_to_49_Years                     0
# 2019_Total_Population:_50_to_54_Years                     0
# 2019_Total_Population:_55_to_59_Years                     0
# 2019_Total_Population:_60_to_64_Years                     0
# 2019_Total_Population:_65_to_69_Years                     0
# 2019_Population_Age_25+_by_Educational_Attainment_Base    0
# 2019_Pop_Age_25+:_No_Schooling                            0
# 2019_Pop_Age_25+:_9th-12th_(No_Diploma)                   0
# ...

# %%
# Get data types for the DataFrame.
acs_df.dtypes
# Out:
# ZIP                                                        int64
# CITY                                                      object
# STATE                                                     object
# 2019_Total_Population:_20_to_24_Years                      int64
# 2019_Total_Population:_25_to_29_Years                      int64
# 2019_Total_Population:_30_to_34_Years                      int64
# 2019_Total_Population:_35_to_39_Years                      int64
# 2019_Total_Population:_40_to_44_Years                      int64
# 2019_Total_Population:_45_to_49_Years                      int64
# 2019_Total_Population:_50_to_54_Years                      int64
# 2019_Total_Population:_55_to_59_Years                      int64
# 2019_Total_Population:_60_to_64_Years                      int64
# 2019_Total_Population:_65_to_69_Years                      int64
# 2019_Population_Age_25+_by_Educational_Attainment_Base     int64
# ...

# %%
# Saving the DataFrame as a csv
acs_df.to_csv('cleaned_acs.csv')
