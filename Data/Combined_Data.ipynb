# %%
# Merging Data

# %%
# Importing dependancies
import pandas as pd

# %%
# Read files
acs = pd.read_csv("Cleaning Data/Cleaned Data/cleaned_acs.csv")
demo = pd.read_csv("Cleaning Data/Cleaned Data/cleaned_demographic.csv")
costco = pd.read_csv("Cleaning Data/Cleaned Data/cleaned_costco.csv")

# %%
# ACS Demo merge one
acs_demo_merge = acs.merge(demo, on='ZIP', how="outer")

# Merged
merged = acs_demo_merge.merge(costco, on='ZIP', how="outer")

# %%
# Dropping Columns
merged = merged.drop('Unnamed: 0_x', axis=1)
merged = merged.drop('Unnamed: 0_y', axis=1)
merged = merged.drop('longitude', axis=1)
merged = merged.drop('latitude', axis=1)
merged = merged.drop('CITY_y', axis=1)
merged = merged.drop('STATE_y', axis=1)
merged = merged.drop('ADDRESS', axis=1)

# %%
# Adding '0' for Zip Codes
merged['ZIP'] = merged['ZIP'].apply(lambda x : str(x).zfill(5))

# %%
merged
# Out:
#          ZIP       CITY_x STATE_x  2019_Total_Population:_20_to_24_Years  \
# 0      01001       Agawam      MA                                    650
# 1      01002      Amherst      MA                                  11249
# 2      01003      Amherst      MA                                   2734
# 3      01005        Barre      MA                                    414
# 4      01007  Belchertown      MA                                   1252
# ...      ...          ...     ...                                    ...
# 32109  99923        Hyder      AK                                      0
# 32110  99925      Klawock      AK                                     41
# 32111  99926   Metlakatla      AK                                    107
# 32112  99929     Wrangell      AK                                     51
# 32113  99950    Ketchikan      AK                                     30
#
#        2019_Total_Population:_25_to_29_Years  \
# 0                                       1027
# 1                                       2023
# 2                                         31
# 3                                        213
# 4                                        597
# ...                                      ...
# 32109                                      0
# 32110                                     47
# 32111                                    120
# 32112                                    186
# 32113                                     49
#
#        2019_Total_Population:_30_to_34_Years  \
# 0                                       1153
# 1                                       1344
# 2                                          0
# 3                                        310
# 4                                        755
# ...                                      ...
# 32109                                      0
# 32110                                     52
# 32111                                    109
# 32112                                    113
# 32113                                     50
#
#        2019_Total_Population:_35_to_39_Years  \
# 0                                        773
# 1                                       1017
# 2                                          7
# 3                                        121
# 4                                        987
# ...                                      ...
# 32109                                      0
# 32110                                     26
# 32111                                     95
# 32112                                     96
# 32113                                     70
#
#        2019_Total_Population:_40_to_44_Years  \
# 0                                       1217
# 1                                        951
# 2                                          0
# 3                                        149
# 4                                        823
# ...                                      ...
# 32109                                      0
# 32110                                     41
# 32111                                     79
# 32112                                    126
# 32113                                     61
#
#        2019_Total_Population:_45_to_49_Years  \
# 0                                       1038
# 1                                       1012
# 2                                          0
# 3                                        475
# 4                                       1113
# ...                                      ...
# 32109                                      0
# 32110                                     71
# 32111                                    104
# 32112                                    181
# 32113                                     67
#
#        2019_Total_Population:_50_to_54_Years  ...  \
# 0                                       1331  ...
# 1                                       1273  ...
# 2                                          0  ...
# 3                                        368  ...
# 4                                       1416  ...
# ...                                      ...  ...
# 32109                                      0  ...
# 32110                                     79  ...
# 32111                                    116  ...
# 32112                                    199  ...
# 32113                                     47  ...
#
#        2019_Median_HH_Income:_HHr_Age_15-24  \
# 0                                     27747
# 1                                     26373
# 2                                      5000
# 3                                      5000
# 4                                     28089
# ...                                     ...
# 32109                                     0
# 32110                                 16902
# 32111                                 27500
# 32112                                 30904
# 32113                                 12915
#
#        2019_Median_HH_Income:_HHr_Age_25-44  \
# 0                                     78863
# 1                                     55775
# 2                                         0
# 3                                     79869
# 4                                    100454
# ...                                     ...
# 32109                                     0
# 32110                                 62061
# 32111                                 62796
# 32112                                 62225
# 32113                                 62498
#
#        2019_Median_HH_Income:_HHr_Age_45-64  \
# 0                                     81899
# 1                                     98699
# 2                                         0
# 3                                     84112
# 4                                    112125
# ...                                     ...
# 32109                                     0
# 32110                                 76387
# 32111                                 76302
# 32112                                 74787
# 32113                                 43053
#
#        2019_Median_HH_Income:_HHr_Age_65+  2021_Median_Household_Income  \
# 0                                   45841                         68392
# 1                                   77235                         63315
# 2                                   87500                          7500
# 3                                   51184                         77915
# 4                                   54294                         97576
# ...                                   ...                           ...
# 32109                               37500                         42500
# 32110                               35443                         51945
# 32111                               32565                         53259
# 32112                               36705                         53451
# 32113                               40000                         44941
#
#        2026_Median_Household_Income  2021_Average_Household_Income  \
# 0                             76174                          87293
# 1                             71008                          93933
# 2                              7500                          12124
# 3                             88169                         107888
# 4                            104725                         115051
# ...                             ...                            ...
# 32109                         42500                          42500
# 32110                         50630                          67266
# 32111                         52375                          65897
# 32112                         54132                          72599
# 32113                         48013                          52908
#
#        2026_Average_Household_Income  \
# 0                              98284
# 1                             104369
# 2                              13505
# 3                             123463
# 4                             128399
# ...                              ...
# 32109                          44118
# 32110                          68683
# 32111                          68394
# 32112                          76792
# 32113                          56569
#
#        2021-2026_Population:_Compound_Annual_Growth_Rate  \
# 0                                                   0.08
# 1                                                   0.27
# 2                                                   0.00
# 3                                                   0.52
# 4                                                   0.53
# ...                                                  ...
# 32109                                               0.59
# 32110                                               0.72
# 32111                                               0.69
# 32112                                               0.24
# 32113                                               0.73
#
#        COSCTO_HEARING_CENTER
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 32109                    NaN
# 32110                    NaN
# 32111                    NaN
# 32112                    NaN
# 32113                    NaN
#
# [32114 rows x 29 columns]

# %%
# Saving the DataFrame as a csv
merged.to_csv('ml_data.csv')
